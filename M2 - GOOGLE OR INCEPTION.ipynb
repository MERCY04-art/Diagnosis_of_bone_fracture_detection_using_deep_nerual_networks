# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import tensorflow
import tensorflow as tf
print(tf.__version__)

import keras
import keras.backend as K
from keras.models import Model
from keras.layers import Input, Dense, Conv2D, Conv3D, DepthwiseConv2D, SeparableConv2D, Conv3DTranspose
from keras.layers import Flatten, MaxPool2D, AvgPool2D, GlobalAvgPool2D, UpSampling2D, BatchNormalization
from keras.layers import Concatenate, Add, Dropout, ReLU, Lambda, Activation, LeakyReLU, PReLU

from IPython.display import SVG


from time import time
import numpy as np

from keras.callbacks import ModelCheckpoint
from tensorflow.keras.callbacks import EarlyStopping

import warnings
warnings.filterwarnings('ignore')
# Out:
# 2.13.0

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

train=ImageDataGenerator(rescale=1./255,shear_range=0.2,zoom_range=0.2,horizontal_flip=True,validation_split = 0.2)
train_data=train.flow_from_directory(directory = 'DATASET/TRAIN',target_size=(224,224),
                                     batch_size=32,class_mode='categorical')
# Out:
# Found 4097 images belonging to 2 classes.

# %%
test=ImageDataGenerator(rescale=1./255)
test_data=test.flow_from_directory(directory = 'DATASET/TEST',target_size=(224,224),
                                   batch_size=32,class_mode='categorical')
# Out:
# Found 3840 images belonging to 2 classes.

# %%
def googlenet(input_shape, n_classes):
  
  def inception_block(x, f):
    t1 = Conv2D(f[0], 1, activation='relu')(x)
    
    t2 = Conv2D(f[1], 1, activation='relu')(x)
    t2 = Conv2D(f[2], 3, padding='same', activation='relu')(t2)
    
    t3 = Conv2D(f[3], 1, activation='relu')(x)
    t3 = Conv2D(f[4], 5, padding='same', activation='relu')(t3)
    
    t4 = MaxPool2D(3, 1, padding='same')(x)
    t4 = Conv2D(f[5], 1, activation='relu')(t4)
    
    output = Concatenate()([t1, t2, t3, t4])
    return output
  
  
  input = Input(input_shape)
  
  x = Conv2D(64, 7, strides=2, padding='same', activation='relu')(input)
  x = MaxPool2D(3, strides=2, padding='same')(x)
  
  x = Conv2D(64, 1, activation='relu')(x)
  x = Conv2D(192, 3, padding='same', activation='relu')(x)
  x = MaxPool2D(3, strides=2)(x)
  
  x = inception_block(x, [64, 96, 128, 16, 32, 32])
  x = inception_block(x, [128, 128, 192, 32, 96, 64])
  x = MaxPool2D(3, strides=2, padding='same')(x)
  
  x = inception_block(x, [192, 96, 208, 16, 48, 64])
  x = inception_block(x, [160, 112, 224, 24, 64, 64])
  x = inception_block(x, [128, 128, 256, 24, 64, 64])
  x = inception_block(x, [112, 144, 288, 32, 64, 64])
  x = inception_block(x, [256, 160, 320, 32, 128, 128])
  x = MaxPool2D(3, strides=2, padding='same')(x)

  x = inception_block(x, [256, 160, 320, 32, 128, 128])
  x = inception_block(x, [384, 192, 384, 48, 128, 128])
  
  x = AvgPool2D(7, strides=1)(x)
  x = Dropout(0.4)(x)
  
  x = Flatten()(x)
  output = Dense(n_classes, activation='softmax')(x)
  
  model = Model(input, output)
  model.compile(optimizer='Adam',loss='categorical_crossentropy',metrics=['accuracy',tensorflow.keras.metrics.Precision()])
  return model
     

input_shape = 224, 224, 3
n_classes = 2

K.clear_session()
model = googlenet(input_shape, n_classes)
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]        0         []
#
#  conv2d (Conv2D)             (None, 112, 112, 64)         9472      ['input_1[0][0]']
#
#  max_pooling2d (MaxPooling2  (None, 56, 56, 64)           0         ['conv2d[0][0]']
#  D)
#
#  conv2d_1 (Conv2D)           (None, 56, 56, 64)           4160      ['max_pooling2d[0][0]']
#
#  conv2d_2 (Conv2D)           (None, 56, 56, 192)          110784    ['conv2d_1[0][0]']
#
#  max_pooling2d_1 (MaxPoolin  (None, 27, 27, 192)          0         ['conv2d_2[0][0]']
#  g2D)
#
#  conv2d_4 (Conv2D)           (None, 27, 27, 96)           18528     ['max_pooling2d_1[0][0]']
#
#  conv2d_6 (Conv2D)           (None, 27, 27, 16)           3088      ['max_pooling2d_1[0][0]']
#
#  max_pooling2d_2 (MaxPoolin  (None, 27, 27, 192)          0         ['max_pooling2d_1[0][0]']
#  g2D)
#
#  conv2d_3 (Conv2D)           (None, 27, 27, 64)           12352     ['max_pooling2d_1[0][0]']
#
#  conv2d_5 (Conv2D)           (None, 27, 27, 128)          110720    ['conv2d_4[0][0]']
#
#  conv2d_7 (Conv2D)           (None, 27, 27, 32)           12832     ['conv2d_6[0][0]']
#
#  conv2d_8 (Conv2D)           (None, 27, 27, 32)           6176      ['max_pooling2d_2[0][0]']
#
#  concatenate (Concatenate)   (None, 27, 27, 256)          0         ['conv2d_3[0][0]',
#                                                                      'conv2d_5[0][0]',
#                                                                      'conv2d_7[0][0]',
#                                                                      'conv2d_8[0][0]']
#
#  conv2d_10 (Conv2D)          (None, 27, 27, 128)          32896     ['concatenate[0][0]']
#
#  conv2d_12 (Conv2D)          (None, 27, 27, 32)           8224      ['concatenate[0][0]']
#
#  max_pooling2d_3 (MaxPoolin  (None, 27, 27, 256)          0         ['concatenate[0][0]']
#  g2D)
#
#  conv2d_9 (Conv2D)           (None, 27, 27, 128)          32896     ['concatenate[0][0]']
#
#  conv2d_11 (Conv2D)          (None, 27, 27, 192)          221376    ['conv2d_10[0][0]']
#
#  conv2d_13 (Conv2D)          (None, 27, 27, 96)           76896     ['conv2d_12[0][0]']
#
#  conv2d_14 (Conv2D)          (None, 27, 27, 64)           16448     ['max_pooling2d_3[0][0]']
#
#  concatenate_1 (Concatenate  (None, 27, 27, 480)          0         ['conv2d_9[0][0]',
#  )                                                                   'conv2d_11[0][0]',
#                                                                      'conv2d_13[0][0]',
#                                                                      'conv2d_14[0][0]']
#
#  max_pooling2d_4 (MaxPoolin  (None, 14, 14, 480)          0         ['concatenate_1[0][0]']
#  g2D)
#
#  conv2d_16 (Conv2D)          (None, 14, 14, 96)           46176     ['max_pooling2d_4[0][0]']
#
#  conv2d_18 (Conv2D)          (None, 14, 14, 16)           7696      ['max_pooling2d_4[0][0]']
#
#  max_pooling2d_5 (MaxPoolin  (None, 14, 14, 480)          0         ['max_pooling2d_4[0][0]']
#  g2D)
#
#  conv2d_15 (Conv2D)          (None, 14, 14, 192)          92352     ['max_pooling2d_4[0][0]']
#
#  conv2d_17 (Conv2D)          (None, 14, 14, 208)          179920    ['conv2d_16[0][0]']
#
#  conv2d_19 (Conv2D)          (None, 14, 14, 48)           19248     ['conv2d_18[0][0]']
#
#  conv2d_20 (Conv2D)          (None, 14, 14, 64)           30784     ['max_pooling2d_5[0][0]']
#
#  concatenate_2 (Concatenate  (None, 14, 14, 512)          0         ['conv2d_15[0][0]',
#  )                                                                   'conv2d_17[0][0]',
#                                                                      'conv2d_19[0][0]',
#                                                                      'conv2d_20[0][0]']
#
#  conv2d_22 (Conv2D)          (None, 14, 14, 112)          57456     ['concatenate_2[0][0]']
#
#  conv2d_24 (Conv2D)          (None, 14, 14, 24)           12312     ['concatenate_2[0][0]']
#
#  max_pooling2d_6 (MaxPoolin  (None, 14, 14, 512)          0         ['concatenate_2[0][0]']
#  g2D)
#
#  conv2d_21 (Conv2D)          (None, 14, 14, 160)          82080     ['concatenate_2[0][0]']
#
#  conv2d_23 (Conv2D)          (None, 14, 14, 224)          226016    ['conv2d_22[0][0]']
#
#  conv2d_25 (Conv2D)          (None, 14, 14, 64)           38464     ['conv2d_24[0][0]']
#
#  conv2d_26 (Conv2D)          (None, 14, 14, 64)           32832     ['max_pooling2d_6[0][0]']
#
#  concatenate_3 (Concatenate  (None, 14, 14, 512)          0         ['conv2d_21[0][0]',
#  )                                                                   'conv2d_23[0][0]',
#                                                                      'conv2d_25[0][0]',
#                                                                      'conv2d_26[0][0]']
#
#  conv2d_28 (Conv2D)          (None, 14, 14, 128)          65664     ['concatenate_3[0][0]']
#
#  conv2d_30 (Conv2D)          (None, 14, 14, 24)           12312     ['concatenate_3[0][0]']
#
#  max_pooling2d_7 (MaxPoolin  (None, 14, 14, 512)          0         ['concatenate_3[0][0]']
#  g2D)
#
#  conv2d_27 (Conv2D)          (None, 14, 14, 128)          65664     ['concatenate_3[0][0]']
#
#  conv2d_29 (Conv2D)          (None, 14, 14, 256)          295168    ['conv2d_28[0][0]']
#
#  conv2d_31 (Conv2D)          (None, 14, 14, 64)           38464     ['conv2d_30[0][0]']
#
#  conv2d_32 (Conv2D)          (None, 14, 14, 64)           32832     ['max_pooling2d_7[0][0]']
#
#  concatenate_4 (Concatenate  (None, 14, 14, 512)          0         ['conv2d_27[0][0]',
#  )                                                                   'conv2d_29[0][0]',
#                                                                      'conv2d_31[0][0]',
#                                                                      'conv2d_32[0][0]']
#
#  conv2d_34 (Conv2D)          (None, 14, 14, 144)          73872     ['concatenate_4[0][0]']
#
#  conv2d_36 (Conv2D)          (None, 14, 14, 32)           16416     ['concatenate_4[0][0]']
#
#  max_pooling2d_8 (MaxPoolin  (None, 14, 14, 512)          0         ['concatenate_4[0][0]']
#  g2D)
#
#  conv2d_33 (Conv2D)          (None, 14, 14, 112)          57456     ['concatenate_4[0][0]']
#
#  conv2d_35 (Conv2D)          (None, 14, 14, 288)          373536    ['conv2d_34[0][0]']
#
#  conv2d_37 (Conv2D)          (None, 14, 14, 64)           51264     ['conv2d_36[0][0]']
#
#  conv2d_38 (Conv2D)          (None, 14, 14, 64)           32832     ['max_pooling2d_8[0][0]']
#
#  concatenate_5 (Concatenate  (None, 14, 14, 528)          0         ['conv2d_33[0][0]',
#  )                                                                   'conv2d_35[0][0]',
#                                                                      'conv2d_37[0][0]',
#                                                                      'conv2d_38[0][0]']
#
#  conv2d_40 (Conv2D)          (None, 14, 14, 160)          84640     ['concatenate_5[0][0]']
#
#  conv2d_42 (Conv2D)          (None, 14, 14, 32)           16928     ['concatenate_5[0][0]']
#
#  max_pooling2d_9 (MaxPoolin  (None, 14, 14, 528)          0         ['concatenate_5[0][0]']
#  g2D)
#
#  conv2d_39 (Conv2D)          (None, 14, 14, 256)          135424    ['concatenate_5[0][0]']
#
#  conv2d_41 (Conv2D)          (None, 14, 14, 320)          461120    ['conv2d_40[0][0]']
#
#  conv2d_43 (Conv2D)          (None, 14, 14, 128)          102528    ['conv2d_42[0][0]']
#
#  conv2d_44 (Conv2D)          (None, 14, 14, 128)          67712     ['max_pooling2d_9[0][0]']
#
#  concatenate_6 (Concatenate  (None, 14, 14, 832)          0         ['conv2d_39[0][0]',
#  )                                                                   'conv2d_41[0][0]',
#                                                                      'conv2d_43[0][0]',
#                                                                      'conv2d_44[0][0]']
#
#  max_pooling2d_10 (MaxPooli  (None, 7, 7, 832)            0         ['concatenate_6[0][0]']
#  ng2D)
#
#  conv2d_46 (Conv2D)          (None, 7, 7, 160)            133280    ['max_pooling2d_10[0][0]']
#
#  conv2d_48 (Conv2D)          (None, 7, 7, 32)             26656     ['max_pooling2d_10[0][0]']
#
#  max_pooling2d_11 (MaxPooli  (None, 7, 7, 832)            0         ['max_pooling2d_10[0][0]']
#  ng2D)
#
#  conv2d_45 (Conv2D)          (None, 7, 7, 256)            213248    ['max_pooling2d_10[0][0]']
#
#  conv2d_47 (Conv2D)          (None, 7, 7, 320)            461120    ['conv2d_46[0][0]']
#
#  conv2d_49 (Conv2D)          (None, 7, 7, 128)            102528    ['conv2d_48[0][0]']
#
#  conv2d_50 (Conv2D)          (None, 7, 7, 128)            106624    ['max_pooling2d_11[0][0]']
#
#  concatenate_7 (Concatenate  (None, 7, 7, 832)            0         ['conv2d_45[0][0]',
#  )                                                                   'conv2d_47[0][0]',
#                                                                      'conv2d_49[0][0]',
#                                                                      'conv2d_50[0][0]']
#
#  conv2d_52 (Conv2D)          (None, 7, 7, 192)            159936    ['concatenate_7[0][0]']
#
#  conv2d_54 (Conv2D)          (None, 7, 7, 48)             39984     ['concatenate_7[0][0]']
#
#  max_pooling2d_12 (MaxPooli  (None, 7, 7, 832)            0         ['concatenate_7[0][0]']
#  ng2D)
#
#  conv2d_51 (Conv2D)          (None, 7, 7, 384)            319872    ['concatenate_7[0][0]']
#
#  conv2d_53 (Conv2D)          (None, 7, 7, 384)            663936    ['conv2d_52[0][0]']
#
#  conv2d_55 (Conv2D)          (None, 7, 7, 128)            153728    ['conv2d_54[0][0]']
#
#  conv2d_56 (Conv2D)          (None, 7, 7, 128)            106624    ['max_pooling2d_12[0][0]']
#
#  concatenate_8 (Concatenate  (None, 7, 7, 1024)           0         ['conv2d_51[0][0]',
#  )                                                                   'conv2d_53[0][0]',
#                                                                      'conv2d_55[0][0]',
#                                                                      'conv2d_56[0][0]']
#
#  average_pooling2d (Average  (None, 1, 1, 1024)           0         ['concatenate_8[0][0]']
#  Pooling2D)
#
#  dropout (Dropout)           (None, 1, 1, 1024)           0         ['average_pooling2d[0][0]']
#
#  flatten (Flatten)           (None, 1024)                 0         ['dropout[0][0]']
#
#  dense (Dense)               (None, 2)                    2050      ['flatten[0][0]']
#
# ==================================================================================================
# Total params: 5975602 (22.80 MB)
# Trainable params: 5975602 (22.80 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %%
model_path = "GOOGLE.h5"

from keras.callbacks import ModelCheckpoint

M = ModelCheckpoint(model_path, monitor='accuracy', verbose=1, save_best_only=True)

# %%
epochs = 35
batch_size = 224

# %%
#### Fitting the model
history = model.fit(
           train_data, steps_per_epoch=train_data.samples // batch_size, 
           epochs=epochs, 
           validation_data=test_data,validation_steps=test_data.samples // batch_size,
           callbacks=[M])
# Out:
# Epoch 1/35
# 18/18 [==============================] - ETA: 0s - loss: 0.6937 - accuracy: 0.5122 - precision: 0.5122
# Epoch 1: accuracy improved from -inf to 0.51215, saving model to GOOGLE.h5
# 18/18 [==============================] - 103s 5s/step - loss: 0.6937 - accuracy: 0.5122 - precision: 0.5122 - val_loss: 0.6962 - val_accuracy: 0.4669 - val_precision: 0.4669
# Epoch 2/35
# 18/18 [==============================] - ETA: 0s - loss: 0.6945 - accuracy: 0.4983 - precision: 0.4983
# Epoch 2: accuracy did not improve from 0.51215
# 18/18 [==============================] - 90s 5s/step - loss: 0.6945 - accuracy: 0.4983 - precision: 0.4983 - val_loss: 0.6921 - val_accuracy: 0.5257 - val_precision: 0.5257
# Epoch 3/35
# 18/18 [==============================] - ETA: 0s - loss: 0.6944 - accuracy: 0.4705 - precision: 0.4705
# Epoch 3: accuracy did not improve from 0.51215
# 18/18 [==============================] - 95s 5s/step - loss: 0.6944 - accuracy: 0.4705 - precision: 0.4705 - val_loss: 0.6937 - val_accuracy: 0.4706 - val_precision: 0.4706
# Epoch 4/35
# 18/18 [==============================] - ETA: 0s - loss: 0.6931 - accuracy: 0.4931 - precision: 0.4931
# Epoch 4: accuracy did not improve from 0.51215
# 18/18 [==============================] - 93s 5s/step - loss: 0.6931 - accuracy: 0.4931 - precision: 0.4931 - val_loss: 0.6945 - val_accuracy: 0.4485 - val_precision: 0.4485
# Epoch 5/35
# 18/18 [==============================] - ETA: 0s - loss: 0.6950 - accuracy: 0.5104 - precision: 0.5104
# Epoch 5: accuracy did not improve from 0.51215
# 18/18 [==============================] - 114s 6s/step - loss: 0.6950 - accuracy: 0.5104 - precision: 0.5104 - val_loss: 0.6945 - val_accuracy: 0.4982 - val_precision: 0.4982
# Epoch 6/35
# 18/18 [==============================] - ETA: 0s - loss: 0.6944 - accuracy: 0.4861 - precision: 0.4861
# Epoch 6: accuracy did not improve from 0.51215
# 18/18 [==============================] - 111s 6s/step - loss: 0.6944 - accuracy: 0.4861 - precision: 0.4861 - val_loss: 0.6932 - val_accuracy: 0.4779 - val_precision: 0.4779
# Epoch 7/35
# 18/18 [==============================] - ETA: 0s - loss: 0.6929 - accuracy: 0.5052 - precision: 0.5052
# Epoch 7: accuracy did not improve from 0.51215
# 18/18 [==============================] - 100s 5s/step - loss: 0.6929 - accuracy: 0.5052 - precision: 0.5052 - val_loss: 0.6932 - val_accuracy: 0.4963 - val_precision: 0.4963
# Epoch 8/35
# 18/18 [==============================] - ETA: 0s - loss: 0.6940 - accuracy: 0.4861 - precision: 0.4861
# Epoch 8: accuracy did not improve from 0.51215
# 18/18 [==============================] - 93s 5s/step - loss: 0.6940 - accuracy: 0.4861 - precision: 0.4861 - val_loss: 0.6935 - val_accuracy: 0.4724 - val_precision: 0.4724
# Epoch 9/35
# 18/18 [==============================] - ETA: 0s - loss: 0.6927 - accuracy: 0.5376 - precision: 0.5376
# Epoch 9: accuracy improved from 0.51215 to 0.53761, saving model to GOOGLE.h5
# 18/18 [==============================] - 91s 5s/step - loss: 0.6927 - accuracy: 0.5376 - precision: 0.5376 - val_loss: 0.6939 - val_accuracy: 0.4688 - val_precision: 0.4688
# Epoch 10/35
# 18/18 [==============================] - ETA: 0s - loss: 0.6925 - accuracy: 0.5347 - precision: 0.5347
# Epoch 10: accuracy did not improve from 0.53761
# 18/18 [==============================] - 92s 5s/step - loss: 0.6925 - accuracy: 0.5347 - precision: 0.5347 - val_loss: 0.6931 - val_accuracy: 0.5037 - val_precision: 0.5037
# Epoch 11/35
# 18/18 [==============================] - ETA: 0s - loss: 0.6934 - accuracy: 0.5035 - precision: 0.5035
# Epoch 11: accuracy did not improve from 0.53761
# 18/18 [==============================] - 95s 5s/step - loss: 0.6934 - accuracy: 0.5035 - precision: 0.5035 - val_loss: 0.6948 - val_accuracy: 0.4632 - val_precision: 0.4632
# Epoch 12/35
# 18/18 [==============================] - ETA: 0s - loss: 0.6937 - accuracy: 0.5101 - precision: 0.5101
# Epoch 12: accuracy did not improve from 0.53761
# 18/18 [==============================] - 92s 5s/step - loss: 0.6937 - accuracy: 0.5101 - precision: 0.5101 - val_loss: 0.6950 - val_accuracy: 0.4853 - val_precision: 0.4853
# Epoch 13/35
# 18/18 [==============================] - ETA: 0s - loss: 0.6925 - accuracy: 0.5226 - precision: 0.5226
# Epoch 13: accuracy did not improve from 0.53761
# 18/18 [==============================] - 76s 4s/step - loss: 0.6925 - accuracy: 0.5226 - precision: 0.5226 - val_loss: 0.6927 - val_accuracy: 0.5147 - val_precision: 0.5147
# Epoch 14/35
# 18/18 [==============================] - ETA: 0s - loss: 0.6935 - accuracy: 0.5035 - precision: 0.5035
# Epoch 14: accuracy did not improve from 0.53761
# 18/18 [==============================] - 98s 5s/step - loss: 0.6935 - accuracy: 0.5035 - precision: 0.5035 - val_loss: 0.6980 - val_accuracy: 0.4412 - val_precision: 0.4412
# Epoch 15/35
# 18/18 [==============================] - ETA: 0s - loss: 0.6931 - accuracy: 0.5087 - precision: 0.5087
# Epoch 15: accuracy did not improve from 0.53761
# 18/18 [==============================] - 98s 5s/step - loss: 0.6931 - accuracy: 0.5087 - precision: 0.5087 - val_loss: 0.6946 - val_accuracy: 0.4761 - val_precision: 0.4761
# Epoch 16/35
# 18/18 [==============================] - ETA: 0s - loss: 0.6936 - accuracy: 0.4948 - precision: 0.4948
# Epoch 16: accuracy did not improve from 0.53761
# 18/18 [==============================] - 97s 5s/step - loss: 0.6936 - accuracy: 0.4948 - precision: 0.4948 - val_loss: 0.6940 - val_accuracy: 0.4761 - val_precision: 0.4761
# Epoch 17/35
# 18/18 [==============================] - ETA: 0s - loss: 0.6934 - accuracy: 0.5017 - precision: 0.5017
# Epoch 17: accuracy did not improve from 0.53761
# 18/18 [==============================] - 96s 5s/step - loss: 0.6934 - accuracy: 0.5017 - precision: 0.5017 - val_loss: 0.6936 - val_accuracy: 0.4724 - val_precision: 0.4724
# Epoch 18/35
# 18/18 [==============================] - ETA: 0s - loss: 0.6936 - accuracy: 0.4807 - precision: 0.4807
# Epoch 18: accuracy did not improve from 0.53761
# 18/18 [==============================] - 96s 5s/step - loss: 0.6936 - accuracy: 0.4807 - precision: 0.4807 - val_loss: 0.6932 - val_accuracy: 0.4963 - val_precision: 0.4963
# Epoch 19/35
# 18/18 [==============================] - ETA: 0s - loss: 0.6938 - accuracy: 0.4826 - precision: 0.4826
# Epoch 19: accuracy did not improve from 0.53761
# 18/18 [==============================] - 98s 5s/step - loss: 0.6938 - accuracy: 0.4826 - precision: 0.4826 - val_loss: 0.6932 - val_accuracy: 0.4816 - val_precision: 0.4816
# Epoch 20/35
# 18/18 [==============================] - ETA: 0s - loss: 0.6931 - accuracy: 0.5087 - precision: 0.5087
# Epoch 20: accuracy did not improve from 0.53761
# 18/18 [==============================] - 101s 6s/step - loss: 0.6931 - accuracy: 0.5087 - precision: 0.5087 - val_loss: 0.6950 - val_accuracy: 0.4393 - val_precision: 0.4393
# Epoch 21/35
# 18/18 [==============================] - ETA: 0s - loss: 0.6934 - accuracy: 0.5028 - precision: 0.5028
# Epoch 21: accuracy did not improve from 0.53761
# 18/18 [==============================] - 96s 5s/step - loss: 0.6934 - accuracy: 0.5028 - precision: 0.5028 - val_loss: 0.6942 - val_accuracy: 0.4908 - val_precision: 0.4908
# Epoch 22/35
# 18/18 [==============================] - ETA: 0s - loss: 0.6959 - accuracy: 0.4549 - precision: 0.4549
# Epoch 22: accuracy did not improve from 0.53761
# 18/18 [==============================] - 98s 5s/step - loss: 0.6959 - accuracy: 0.4549 - precision: 0.4549 - val_loss: 0.6934 - val_accuracy: 0.4540 - val_precision: 0.4540
# Epoch 23/35
# 18/18 [==============================] - ETA: 0s - loss: 0.6932 - accuracy: 0.4948 - precision: 0.4948
# Epoch 23: accuracy did not improve from 0.53761
# 18/18 [==============================] - 96s 5s/step - loss: 0.6932 - accuracy: 0.4948 - precision: 0.4948 - val_loss: 0.6937 - val_accuracy: 0.4651 - val_precision: 0.4651
# Epoch 24/35
# 18/18 [==============================] - ETA: 0s - loss: 0.6933 - accuracy: 0.4844 - precision: 0.4844
# Epoch 24: accuracy did not improve from 0.53761
# 18/18 [==============================] - 103s 6s/step - loss: 0.6933 - accuracy: 0.4844 - precision: 0.4844 - val_loss: 0.6926 - val_accuracy: 0.5460 - val_precision: 0.5460
# Epoch 25/35
# 18/18 [==============================] - ETA: 0s - loss: 0.6934 - accuracy: 0.4861 - precision: 0.4861
# Epoch 25: accuracy did not improve from 0.53761
# 18/18 [==============================] - 98s 5s/step - loss: 0.6934 - accuracy: 0.4861 - precision: 0.4861 - val_loss: 0.6927 - val_accuracy: 0.5257 - val_precision: 0.5257
# Epoch 26/35
# 18/18 [==============================] - ETA: 0s - loss: 0.6932 - accuracy: 0.5087 - precision: 0.5087
# Epoch 26: accuracy did not improve from 0.53761
# 18/18 [==============================] - 106s 6s/step - loss: 0.6932 - accuracy: 0.5087 - precision: 0.5087 - val_loss: 0.6937 - val_accuracy: 0.4596 - val_precision: 0.4596
# Epoch 27/35
# 18/18 [==============================] - ETA: 0s - loss: 0.6939 - accuracy: 0.4844 - precision: 0.4844
# Epoch 27: accuracy did not improve from 0.53761
# 18/18 [==============================] - 94s 5s/step - loss: 0.6939 - accuracy: 0.4844 - precision: 0.4844 - val_loss: 0.6941 - val_accuracy: 0.4393 - val_precision: 0.4393
# Epoch 28/35
# 18/18 [==============================] - ETA: 0s - loss: 0.6931 - accuracy: 0.4896 - precision: 0.4896
# Epoch 28: accuracy did not improve from 0.53761
# 18/18 [==============================] - 97s 5s/step - loss: 0.6931 - accuracy: 0.4896 - precision: 0.4896 - val_loss: 0.6932 - val_accuracy: 0.4614 - val_precision: 0.4614
# Epoch 29/35
# 18/18 [==============================] - ETA: 0s - loss: 0.6931 - accuracy: 0.5087 - precision: 0.5087
# Epoch 29: accuracy did not improve from 0.53761
# 18/18 [==============================] - 112s 6s/step - loss: 0.6931 - accuracy: 0.5087 - precision: 0.5087 - val_loss: 0.6929 - val_accuracy: 0.5221 - val_precision: 0.5221
# Epoch 30/35
# 18/18 [==============================] - ETA: 0s - loss: 0.6933 - accuracy: 0.4826 - precision: 0.4826
# Epoch 30: accuracy did not improve from 0.53761
# 18/18 [==============================] - 110s 6s/step - loss: 0.6933 - accuracy: 0.4826 - precision: 0.4826 - val_loss: 0.6928 - val_accuracy: 0.5221 - val_precision: 0.5221
# Epoch 31/35
# 18/18 [==============================] - ETA: 0s - loss: 0.6930 - accuracy: 0.5191 - precision: 0.5191
# Epoch 31: accuracy did not improve from 0.53761
# 18/18 [==============================] - 86s 5s/step - loss: 0.6930 - accuracy: 0.5191 - precision: 0.5191 - val_loss: 0.6926 - val_accuracy: 0.5202 - val_precision: 0.5202
# Epoch 32/35
# 18/18 [==============================] - ETA: 0s - loss: 0.6921 - accuracy: 0.5330 - precision: 0.5330
# Epoch 32: accuracy did not improve from 0.53761
# 18/18 [==============================] - 85s 5s/step - loss: 0.6921 - accuracy: 0.5330 - precision: 0.5330 - val_loss: 0.6899 - val_accuracy: 0.5607 - val_precision: 0.5607
# Epoch 33/35
# 18/18 [==============================] - ETA: 0s - loss: 0.6926 - accuracy: 0.5295 - precision: 0.5295
# Epoch 33: accuracy did not improve from 0.53761
# 18/18 [==============================] - 85s 5s/step - loss: 0.6926 - accuracy: 0.5295 - precision: 0.5295 - val_loss: 0.6915 - val_accuracy: 0.5331 - val_precision: 0.5331
# Epoch 34/35
# 18/18 [==============================] - ETA: 0s - loss: 0.6950 - accuracy: 0.4740 - precision: 0.4740
# Epoch 34: accuracy did not improve from 0.53761
# 18/18 [==============================] - 86s 5s/step - loss: 0.6950 - accuracy: 0.4740 - precision: 0.4740 - val_loss: 0.6924 - val_accuracy: 0.5221 - val_precision: 0.5221
# Epoch 35/35
# 18/18 [==============================] - ETA: 0s - loss: 0.6933 - accuracy: 0.5122 - precision: 0.5122
# Epoch 35: accuracy did not improve from 0.53761
# 18/18 [==============================] - 86s 5s/step - loss: 0.6933 - accuracy: 0.5122 - precision: 0.5122 - val_loss: 0.6932 - val_accuracy: 0.5000 - val_precision: 0.5000

# %%
history.history.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'precision', 'val_loss', 'val_accuracy', 'val_precision'])

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.figure(figsize=(20, 8))
plt.plot(history.history['accuracy'])

for i in range(epochs):
    if i%5 == 0:
        plt.annotate(np.round(history.history['accuracy'][i]*100,2),xy=(i,history.history['accuracy'][i]))

plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.show()

# %%
plt.figure(figsize=(20, 8))
plt.plot(history.history['loss'])

for i in range(epochs):
    if i%5 == 0:
        plt.annotate(np.round(history.history['loss'][i]*100,2),xy=(i,history.history['loss'][i]))

plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.show()

# %%
plt.figure(figsize=(20, 8))
plt.plot(history.history['precision'])

for i in range(epochs):
    if i%5 == 0:
        plt.annotate(np.round(history.history['loss'][i]*100,2),xy=(i,history.history['precision'][i]))

plt.title('Model precision')
plt.ylabel('precision')
plt.xlabel('Epoch')
plt.show()

# %%
import matplotlib.pyplot as plt

def graph():
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('Model loss')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Test'], loc='upper left')
    plt.show()
graph()

# %%
import matplotlib.pyplot as plt

def graph():
    #Plot training & validation accuracy values
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title('Model accuracy')
    plt.ylabel('Accuracy')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Test'], loc='upper left')
    plt.show()

graph()
